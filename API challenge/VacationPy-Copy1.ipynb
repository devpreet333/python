# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities = pd.read_csv("../output_data/cities.csv")

# First overview the data set - how many factors, etc.
cities.head()
# Out:
#            city  cloudiness Country        Date  Humidity    lat     lon  \
# 0       Honiara          20      SB  1585000092        94  -9.43  159.95
# 1  Ponta do Sol          40      PT  1585000093        67  32.67  -17.10
# 2         Pevek         100      RU  1585000093        86  69.70  170.31
# 3     Wonthaggi          87      AU  1585000094        75 -38.60  145.59
# 4       Ushuaia          75      AR  1585000095        67 -54.80  -68.30
#
#    Max Temp  Wind Speed
# 0     26.00        1.02
# 1     17.00        6.70
# 2     -7.43        6.64
# 3     14.44        0.45
# 4     14.00        9.80

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
locations = cities[["lat", "lon"]].astype(float)

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
cities_complete = cities.dropna()
humidity = cities["Humidity"].astype(float)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
cities_ideal = cities.loc[ cities['Max Temp'] <= 25]
cities_ideal = cities_ideal.loc[ cities_ideal['Max Temp'] > 5]
cities_ideal = cities_ideal.loc[ cities_ideal['Wind Speed'] < 10]
cities_ideal = cities_ideal.loc[ cities_ideal['cloudiness'] < 50]
cities_ideal
# Out:
#                         city  cloudiness Country        Date  Humidity    lat  \
# 1               Ponta do Sol          40      PT  1585000093        67  32.67
# 8      Los Llanos de Aridane          20      ES  1585000097        55  28.66
# 18                 Carnarvon           0      AU  1585000104        69 -24.87
# 27                    Shingū           0      JP  1585000115        53  33.73
# 29                      Chui          41      UY  1585000116        65 -33.70
# ..                       ...         ...     ...         ...       ...    ...
# 499  Arroyo de la Encomienda           6      ES  1585000535        87  41.61
# 502                 Katsuura          20      JP  1585000539        48  35.13
# 507                   Zhuhai          40      CN  1585000543        94  22.28
# 534                   Eureka          40      US  1585000339        62  40.80
# 549               Alexandria           0      EG  1585000492        77  31.22
#
#         lon  Max Temp  Wind Speed
# 1    -17.10     17.00        6.70
# 8    -17.92     19.00        9.80
# 18   113.63     24.00        3.10
# 27   135.98      7.77        4.55
# 29   -53.46     23.77        6.19
# ..      ...       ...         ...
# 499   -4.80     10.56        4.10
# 502  140.30      7.00        9.30
# 507  113.57     22.78        5.10
# 534 -124.16     12.78        2.80
# 549   29.96     16.00        2.10
#
# [109 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
import json
hotel_df = []
locations1 = cities_ideal[["lat", "lon"]].astype(float)
for index, row in cities_ideal.iterrows():
    try:
        target_lat = float(row["lat"])
        target_lon = float(row["lon"])
        target_coordinates = row["lat"], row["lon"]
        #target_coordinates = "32.67, -17.1"
        #print (target_coordinates)
        target_search = "Hotel"
        target_radius = 5000
        target_type = "lodging"
        params = {

            "keyword": target_search,
            "radius": target_radius,
            "type": target_type,
            "key": g_key
        }
        
        # base url
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362"
        base_url1 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=" + str (row["lat"]) +"," + str(row["lon"]) 
        
        # run a request using our params dictionary
        response = requests.get(base_url1, params=params)

        # convert response to json
        places_data = response.json()

        print(places_data["results"][0]["name"])
        hotel_df.append(places_data["results"][0]["name"])
    except IndexError:
        hotel_df.append("NA")
        print("Hotel not found. Skipping...")
print(hotel_df)
print (len(hotel_df))
# Out:
# Hotel Da Vila
# Hotel Hacienda de Abajo
# Hospitality Carnarvon
# Gran Hotel
# Bertelli Chuí Hotel
# HOtel Tasiast
# Kunda Hotel
# Central Palace Hotel - Castro (PR)
# J hotel @Bandara Soekarno Hatta
# Hotel Brisas De Comarapa
# Hôtel Djamtum
# Cape Fox Lodge
# Sands Hotel Margate
# Hotel Xaguate
# Hotel Izukyu
# Vinpearl Hotel Quảng Bình
# Old Colony Inn
# Quest Hotel San Denpasar
# Hotel Grand Chancellor Hobart
# 花しぶき（満開のおもてなし）
# The Harbourview
# Novomar Pousada e Turismo Ltda
# Desert Gardens Hotel - Ayers Rock Resort
# Hotel not found. Skipping...
# Noto Wajima Onsen Hotel Koshuen
# Nino village
# Lakeview Hotel Motel
# Kasa Resort
# Crest Hotel
# Quality Inn
# Odar kanawal
# Pousada Kactus
# Hotel Porto Santo & Spa
# Orlanova Hotel
# Lilin Lovina Beach Hotel
# Hotel not found. Skipping...
# Hotel Karibu
# 7 Days Premium
# Mercure Alice Springs Resort
# Sittwe Hotel
# Champagnat Praia Hotel
# Napakuang Resort
# Yadav Hotel
# Desert Rendezvous
# Hôtel Bel-Air
# Mission Of The Sun Hotel
# Hotel not found. Skipping...
# Hotel VIP Praia
# Hotel Frontera La Quiaca
# Mövenpick Hotel Qassim
# Yeppoon Beach House
# Bed & Breakfast Sweet Dreams
# Premier Hotels & Resorts
# yKalinga Hotel
# Hotel not found. Skipping...
# Magnolias Cottage
# Beachfront Voyager Motor Inn
# ASTON Kupang Hotel & Convention Center
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Wanda Realm Jining
# Hotel National
# Jinjiang Inn Pu'er Zhenxing Avenue
# Hotel La Cabane
# Hotel KAN-RAKU Honjo Waseda Ekimae
# Obelix Guesthouse
# Pyramisa Island Hotel Aswan
# Don Felix
# Nouackchott Hotel
# Embassy Suites by Hilton Mandalay Beach Resort
# Hotel not found. Skipping...
# Hotel Jardim Bulevard
# Hotel not found. Skipping...
# @HOM Premiere Tambun
# Blackwater Central Motel
# Angora Hotel
# Itapema Beach Hotéis e Resorts
# Kemping wifi hotel
# Mirel Hotel
# Hotel Castel Victoria
# Hotel not found. Skipping...
# B&B Sunrise House Aygavan
# Hotel not found. Skipping...
# Hotel Timor
# Hotel 3 Anges
# Abaco Beach Resort
# Ocean Purring Views
# Murud Marina Hotel
# Toba Kokusai Hotel
# Al Bustan Palace, A Ritz-Carlton Hotel
# Aspen Suites Hotel Sitka
# Casa Rodo 53
# Эрхэт зочид буудал
# Hotel New Amami
# HOTEL PLAZA
# DoubleTree by Hilton Hotel Wuhu
# CityHub Rotterdam
# Dolphin Hotel
# 万宁日月湾酒店
# Xiaocheng Zhichun Holiday Inn
# Raoum Inn Hotel
# Hotel not found. Skipping...
# Jalu Hotel
# AC Hotel by Marriott Palacio de Santa Ana
# Katsuura Hotel Mikazuki
# Pullman Zhuhai
# Best Western Plus Bayshore Inn
# TOLIP Hotel Alexandria
# ['Hotel Da Vila', 'Hotel Hacienda de Abajo', 'Hospitality Carnarvon', 'Gran Hotel', 'Bertelli Chuí Hotel', 'HOtel Tasiast', 'Kunda Hotel', 'Central Palace Hotel - Castro (PR)', 'J hotel @Bandara Soekarno Hatta', 'Hotel Brisas De Comarapa', 'Hôtel Djamtum', 'Cape Fox Lodge', 'Sands Hotel Margate', 'Hotel Xaguate', 'Hotel Izukyu', 'Vinpearl Hotel Quảng Bình', 'Old Colony Inn', 'Quest Hotel San Denpasar', 'Hotel Grand Chancellor Hobart', '花しぶき（満開のおもてなし）', 'The Harbourview', 'Novomar Pousada e Turismo Ltda', 'Desert Gardens Hotel - Ayers Rock Resort', 'NA', 'Noto Wajima Onsen Hotel Koshuen', 'Nino village', 'Lakeview Hotel Motel', 'Kasa Resort', 'Crest Hotel', 'Quality Inn', 'Odar kanawal', 'Pousada Kactus', 'Hotel Porto Santo & Spa', 'Orlanova Hotel', 'Lilin Lovina Beach Hotel', 'NA', 'Hotel Karibu', '7 Days Premium', 'Mercure Alice Springs Resort', 'Sittwe Hotel', 'Champagnat Praia Hotel', 'Napakuang Resort', 'Yadav Hotel', 'Desert Rendezvous', 'Hôtel Bel-Air', 'Mission Of The Sun Hotel', 'NA', 'Hotel VIP Praia', 'Hotel Frontera La Quiaca', 'Mövenpick Hotel Qassim', 'Yeppoon Beach House', 'Bed & Breakfast Sweet Dreams', 'Premier Hotels & Resorts', 'yKalinga Hotel', 'NA', 'Magnolias Cottage', 'Beachfront Voyager Motor Inn', 'ASTON Kupang Hotel & Convention Center', 'NA', 'NA', 'NA', 'Wanda Realm Jining', 'Hotel National', "Jinjiang Inn Pu'er Zhenxing Avenue", 'Hotel La Cabane', 'Hotel KAN-RAKU Honjo Waseda Ekimae', 'Obelix Guesthouse', 'Pyramisa Island Hotel Aswan', 'Don Felix', 'Nouackchott Hotel', 'Embassy Suites by Hilton Mandalay Beach Resort', 'NA', 'Hotel Jardim Bulevard', 'NA', '@HOM Premiere Tambun', 'Blackwater Central Motel', 'Angora Hotel', 'Itapema Beach Hotéis e Resorts', 'Kemping wifi hotel', 'Mirel Hotel', 'Hotel Castel Victoria', 'NA', 'B&B Sunrise House Aygavan', 'NA', 'Hotel Timor', 'Hotel 3 Anges', 'Abaco Beach Resort', 'Ocean Purring Views', 'Murud Marina Hotel', 'Toba Kokusai Hotel', 'Al Bustan Palace, A Ritz-Carlton Hotel', 'Aspen Suites Hotel Sitka', 'Casa Rodo 53', 'Эрхэт зочид буудал', 'Hotel New Amami', 'HOTEL PLAZA', 'DoubleTree by Hilton Hotel Wuhu', 'CityHub Rotterdam', 'Dolphin Hotel', '万宁日月湾酒店', 'Xiaocheng Zhichun Holiday Inn', 'Raoum Inn Hotel', 'NA', 'Jalu Hotel', 'AC Hotel by Marriott Palacio de Santa Ana', 'Katsuura Hotel Mikazuki', 'Pullman Zhuhai', 'Best Western Plus Bayshore Inn', 'TOLIP Hotel Alexandria']
# 109

# %%
cities_ideal["Hotel Name"] = hotel_df
cities_ideal
# Out:
#                         city  cloudiness Country        Date  Humidity    lat  \
# 1               Ponta do Sol          40      PT  1585000093        67  32.67
# 8      Los Llanos de Aridane          20      ES  1585000097        55  28.66
# 18                 Carnarvon           0      AU  1585000104        69 -24.87
# 27                    Shingū           0      JP  1585000115        53  33.73
# 29                      Chui          41      UY  1585000116        65 -33.70
# ..                       ...         ...     ...         ...       ...    ...
# 499  Arroyo de la Encomienda           6      ES  1585000535        87  41.61
# 502                 Katsuura          20      JP  1585000539        48  35.13
# 507                   Zhuhai          40      CN  1585000543        94  22.28
# 534                   Eureka          40      US  1585000339        62  40.80
# 549               Alexandria           0      EG  1585000492        77  31.22
#
#         lon  Max Temp  Wind Speed                                 Hotel Name
# 1    -17.10     17.00        6.70                              Hotel Da Vila
# 8    -17.92     19.00        9.80                    Hotel Hacienda de Abajo
# 18   113.63     24.00        3.10                      Hospitality Carnarvon
# 27   135.98      7.77        4.55                                 Gran Hotel
# 29   -53.46     23.77        6.19                        Bertelli Chuí Hotel
# ..      ...       ...         ...                                        ...
# 499   -4.80     10.56        4.10  AC Hotel by Marriott Palacio de Santa Ana
# 502  140.30      7.00        9.30                    Katsuura Hotel Mikazuki
# 507  113.57     22.78        5.10                             Pullman Zhuhai
# 534 -124.16     12.78        2.80             Best Western Plus Bayshore Inn
# 549   29.96     16.00        2.10                     TOLIP Hotel Alexandria
#
# [109 rows x 10 columns]

# %%
locations1 = cities_ideal[["lat", "lon"]].astype(float)
for index, row in locations1.iterrows():
    #print(row['c1'], row['c2'])
    target_coordinates = row["lat"], row["lon"]
    print (target_coordinates)
# Out:
# (32.67, -17.1)
# (28.66, -17.92)
# (-24.87, 113.63)
# (33.73, 135.98)
# (-33.7, -53.46)
# (20.93, -17.03)
# (30.99, 103.94)
# (-24.79, -50.01)
# (-6.1, 106.64)
# (-17.9, -64.48)
# (11.32, -12.28)
# (55.34, -131.65)
# (51.38, 1.39)
# (14.9, -24.5)
# (34.67, 138.95)
# (17.48, 106.6)
# (-42.78, 147.06)
# (-8.65, 115.22)
# (-42.88, 147.33)
# (34.98, 139.87)
# (22.29, 114.16)
# (-30.18, -50.21)
# (-25.24, 130.99)
# (-8.93, 125.41)
# (37.4, 136.9)
# (41.96, 42.96)
# (-34.58, 150.86)
# (27.63, 93.83)
# (54.32, -130.32)
# (44.37, -100.35)
# (20.52, -13.05)
# (-21.64, -41.05)
# (33.08, -16.33)
# (-22.97, -42.03)
# (-8.19, 114.97)
# (6.71, 121.97)
# (-2.95, 25.95)
# (42.8, 93.45)
# (-23.7, 133.88)
# (20.15, 92.9)
# (-20.33, -40.29)
# (18.5, 102.42)
# (22.85, 82.2)
# (-22.12, 14.28)
# (44.9, -0.72)
# (21.27, -97.45)
# (22.68, -3.98)
# (14.92, -23.51)
# (-22.09, -65.59)
# (26.33, 43.98)
# (-23.13, 150.73)
# (-35.33, -72.42)
# (-33.02, 27.91)
# (17.42, 121.44)
# (6.98, 39.18)
# (40.16, -8.33)
# (-41.07, 145.92)
# (-10.17, 123.58)
# (29.11, 21.29)
# (18.39, 42.45)
# (36.1, 0.42)
# (35.41, 116.58)
# (-13.2, 49.05)
# (22.79, 100.97)
# (18.65, -74.12)
# (36.23, 139.18)
# (-26.65, 15.16)
# (24.09, 32.91)
# (-29.95, -71.34)
# (18.09, -15.98)
# (34.15, -119.2)
# (29.16, 16.14)
# (-27.41, -49.6)
# (6.12, 81.12)
# (-6.26, 107.07)
# (-23.58, 148.88)
# (-24.7, 44.75)
# (-27.09, -48.61)
# (41.32, 61.07)
# (37.51, 34.05)
# (50.52, 1.63)
# (39.72, 45.65)
# (39.83, 44.7)
# (-35.1, 173.78)
# (-9.11, 124.89)
# (3.25, 19.77)
# (26.54, -77.06)
# (-35.62, 174.5)
# (18.33, 72.97)
# (34.48, 136.85)
# (23.61, 58.59)
# (57.05, -135.33)
# (-34.48, -54.33)
# (46.68, 113.28)
# (28.37, 129.48)
# (-25.4, -70.48)
# (31.34, 118.38)
# (51.92, 4.48)
# (50.62, -3.4)
# (18.8, 110.4)
# (19.91, 109.69)
# (29.97, 40.21)
# (6.48, 38.52)
# (29.03, 21.55)
# (41.61, -4.8)
# (35.13, 140.3)
# (22.28, 113.57)
# (40.8, -124.16)
# (31.22, 29.96)

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in cities_ideal.iterrows()]
locations = cities_ideal[["lat", "lon"]]

# %%
# Add marker layer ontop of heat map
import gmplot
place_layer = gmap3.scatter( cities_ideal[["lat"]], cities_ideal[["lon"]], '# FF0000', 
                              size = 40, marker = False )

gmap.heatmap(latitude, longitude)
gmap.scatter(latitude, longitude, c='r', marker=True)
#heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
  #                               dissipating=False, max_intensity=100,
#                              point_radius = 2)
gmap3.draw
# Display Map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7f4365eaf7cb> in <module>
#       1 # Add marker layer ontop of heat map
#       2 import gmplot
# ----> 3 place_layer = gmap3.scatter( cities_ideal[["lat"]], cities_ideal[["lon"]], '# FF0000',
#       4                               size = 40, marker = False )
#       5
#
# NameError: name 'gmap3' is not defined

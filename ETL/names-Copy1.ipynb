# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'IMDb names.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1    nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3    nm0000004     John Belushi        John Adam Belushi   173.0
# 4    nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                        birth_details  birth_year  \
# 0              May 10, 1899 inÂ Omaha, Nebraska, USA      1899.0
# 1  September 16, 1924 inÂ The Bronx, New York Cit...      1924.0
# ...

# %%
df_clean = df.drop(columns = ['birth_name','bio', 'birth_details', 'death_details','date_of_death', 'place_of_death', 'reason_of_death', 'divorces','spouses', 'spouses_with_children', 'children']).copy()
df_clean.head()
# Out:
#   imdb_name_id             name  height  birth_year date_of_birth  \
# 0    nm0000001     Fred Astaire   177.0      1899.0    1899-05-10
# 1    nm0000002    Lauren Bacall   174.0      1924.0    1924-09-16
# 2    nm0000003  Brigitte Bardot   166.0      1934.0    1934-09-28
# 3    nm0000004     John Belushi   173.0      1949.0    1949-01-24
# 4    nm0000005   Ingmar Bergman   179.0      1918.0    1918-07-14
#
#                             place_of_birth  death_year  \
# 0                     Omaha, Nebraska, USA      1987.0
# 1  The Bronx, New York City, New York, USA      2014.0
# 2                            Paris, France         NaN
# 3                   Chicago, Illinois, USA      1982.0
# 4            Uppsala, Uppsala lÃ¤n, Sweden      2007.0
#
#                primary_profession                         known_for_titles
# 0  soundtrack,actor,miscellaneous  tt0050419,tt0053137,tt0072308,tt0043044
# 1              actress,soundtrack  tt0037382,tt0038355,tt0117057,tt0071877
# ...

# %%
# Delete extraneous column
# df_clean_filter = df_clean[(df_clean['death_year'] == "") | (df_clean['death_year'] > 2016)] 
# df_clean_filter

# %%
df_clean_filter = df_clean[pd.isnull(df_clean['death_year']) | (df_clean['death_year'] > 2016)] 
df_clean_filter
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
names_data = df_clean_filter.drop(columns = ['death_year']).copy()
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
# Identify incomplete rows
names_data.count()
# Out:
# imdb_name_id          150608
# name                  150608
# height                 25342
# birth_year             50525
# date_of_birth          50538
# place_of_birth         47579
# primary_profession    150242
# known_for_titles      149645
# dtype: int64

# %%
names_data.dtypes
# Out:
# imdb_name_id           object
# name                   object
# height                float64
# birth_year            float64
# date_of_birth          object
# place_of_birth         object
# primary_profession     object
# known_for_titles       object
# dtype: object

# %%
s.str.rsplit("/", n=1, expand=True)

# %%
new = names_data["place_of_birth"].str.rsplit(",", n = 1, expand = True)
names_data["place_of_birth"] = new[0]
names_data["country_of_birth"] = new[1]
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
names_data.count()
# Out:
# imdb_name_id          150608
# name                  150608
# height                 25342
# birth_year             50525
# date_of_birth          50538
# place_of_birth         47579
# primary_profession    150242
# known_for_titles      149645
# country_of_birth       44242
# dtype: int64

# %%
names_data['country_of_birth'] = names_data['country_of_birth'].fillna(names_data['place_of_birth'])
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
new = names_data["country_of_birth"].str.split("[", n = 1, expand = True)
names_data["country_of_birth"] = new[0]
names_data["birth_country"] = new[1]
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
names_data['birth_country'] = names_data['birth_country'].fillna(names_data['country_of_birth'])
names_data['birth_country'] = names_data['birth_country'].str.lower()
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
names_data.drop(columns = ['country_of_birth'])
names_data['birth_country'] = names_data['birth_country'].str.strip()
names_data['birth_country'] = names_data['birth_country'].str.rstrip()
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
names_data['birth_country'] = names_data['birth_country'].fillna(names_data['country_of_birth'])
names_data['birth_country'] = names_data['birth_country'].str.lower()
names_data

# %%
names_data['birth_country'] = names_data['birth_country'].str.replace('now ', '')
names_data['birth_country'] = names_data['birth_country'].str.replace(']', '')
names_data['birth_country'] = names_data['birth_country'].replace(
    {'british india': 'india', 'ussr': 'russia', 'portugese india': 'india', 'west germany': 'germany', 
         'east germany': 'germany', 'german democratic republic': 'germany', 'slovak republic' : 'slovakia', 
             'in czech republic' : 'czech republic', 'berlin' :'germany', 'federal republic of germany': 'germany',
                'east pakistan' : 'bangladesh', 'united states' : 'usa', 'london' : 'uk', 'in bangladesh' : 'bangladesh',
                    'former ussr' : 'russia', 'burma' : 'myanmmar', 'united kingdom' : 'uk', 'paris': 'france', 'moscow': 'russia'})
names_data
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 2         nm0000003        Brigitte Bardot   166.0      1934.0    1934-09-28
# 12        nm0000013              Doris Day   170.0      1922.0    1922-04-03
# 13        nm0000014    Olivia de Havilland   163.0      1916.0    1916-07-01
# 17        nm0000018           Kirk Douglas   175.0      1916.0    1916-12-09
# 46        nm0000047           Sophia Loren   175.0      1934.0    1934-09-20
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan     NaN         NaN           NaN
# 175711    nm9991653        Wojciech Rzehak     NaN         NaN           NaN
# 175712    nm9992720       McMagic Cardenas     NaN         NaN           NaN
# 175713    nm9992840    Rashaduzzman Shohag     NaN         NaN           NaN
# 175714    nm9992999         William Plyler     NaN         NaN           NaN
#
# ...

# %%
a = names_data['birth_country'].value_counts().to_frame()
pd.set_option('display.max_rows', a.shape[0]+1)

print(a)
# Out:
#                                                     birth_country
# usa                                                         14439
# uk                                                           3650
# germany                                                      2391
# japan                                                        2015
# france                                                       1827
# italy                                                        1689
# canada                                                       1676
# spain                                                        1247
# russia                                                       1124
# india                                                        1069
# poland                                                        995
# turkey                                                        796
# brazil                                                        773
# ...

# %%
names_data.dtypes
# Out:
# imdb_name_id           object
# name                   object
# height                float64
# birth_year            float64
# date_of_birth          object
# place_of_birth         object
# primary_profession     object
# known_for_titles       object
# country_of_birth       object
# birth_country          object
# dtype: object
